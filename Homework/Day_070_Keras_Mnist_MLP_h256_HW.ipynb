# %% [markdown]
# # 作業:
# [練習]請嘗試新增一層或兩層看看最後預測結果是否有差異
# model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))

# %% [markdown]
# # 資料預處理

# %%
from keras.utils import np_utils
import numpy as np
np.random.seed(10)
# Out:
# Using TensorFlow backend.

# %%
#載入手寫辨識的資料集
from keras.datasets import mnist
(x_train_image,y_train_label),\
(x_test_image,y_test_label)= mnist.load_data()

# %%
#指定測試集與訓練資料集
x_Train =x_train_image.reshape(60000, 784).astype('float32')
x_Test = x_test_image.reshape(10000, 784).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
x_Train_normalize = x_Train / 255
x_Test_normalize = x_Test / 255

# %%
#把LABEL轉成NUMERICAL Categorical 
y_Train_OneHot = np_utils.to_categorical(y_train_label)
y_Test_OneHot = np_utils.to_categorical(y_test_label)

# %%
x_Train_normalize.shape
# Out:
# (60000, 784)

# %% [markdown]
# # 建立模型

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
#建立模型
model = Sequential()

# %%
model.add(Dense(input_shape = (784,), units=256, 
                kernel_initializer='normal', 
                activation='relu'))

model.add(Dense(units = 256, kernel_initializer='normal', activation='sigmoid'))

model.add(Dropout(rate = 0.8))

model.add(Dense(units = 256, kernel_initializer='normal', activation='sigmoid'))

model.add(Dense(units=10, 
                kernel_initializer='normal', 
                activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 335,114
# Trainable params: 335,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 訓練模型

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %%
train_history =model.fit(x=x_Train_normalize,
                         y=y_Train_OneHot,validation_split=0.2, 
                         epochs=10, batch_size=32,verbose=1)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 9s 189us/step - loss: 0.5085 - acc: 0.8501 - val_loss: 0.1628 - val_acc: 0.9534
# Epoch 2/10
# 48000/48000 [==============================] - 9s 181us/step - loss: 0.1901 - acc: 0.9453 - val_loss: 0.1208 - val_acc: 0.9652
# Epoch 3/10
# 48000/48000 [==============================] - 9s 180us/step - loss: 0.1368 - acc: 0.9620 - val_loss: 0.1197 - val_acc: 0.9654
# Epoch 4/10
# 48000/48000 [==============================] - 9s 181us/step - loss: 0.1096 - acc: 0.9689 - val_loss: 0.0991 - val_acc: 0.9731
# Epoch 5/10
# 48000/48000 [==============================] - 9s 182us/step - loss: 0.0894 - acc: 0.9742 - val_loss: 0.0931 - val_acc: 0.9739
# Epoch 6/10
# 48000/48000 [==============================] - 9s 181us/step - loss: 0.0783 - acc: 0.9772 - val_loss: 0.0964 - val_acc: 0.9740
# Epoch 7/10
# 48000/48000 [==============================] - 9s 181us/step - loss: 0.0679 - acc: 0.9803 - val_loss: 0.0994 - val_acc: 0.9750
# Epoch 8/10
# 48000/48000 [==============================] - 9s 181us/step - loss: 0.0597 - acc: 0.9820 - val_loss: 0.0976 - val_acc: 0.9767
# Epoch 9/10
# 48000/48000 [==============================] - 9s 180us/step - loss: 0.0526 - acc: 0.9838 - val_loss: 0.1071 - val_acc: 0.9763
# Epoch 10/10
# 48000/48000 [==============================] - 9s 181us/step - loss: 0.0482 - acc: 0.9856 - val_loss: 0.0916 - val_acc: 0.9799

# %% [markdown]
# # 以圖形顯示訓練過程

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
show_train_history(train_history,'acc','val_acc')

# %%
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# # 評估模型準確率

# %%
scores = model.evaluate(x_Test_normalize, y_Test_OneHot)
print()
print('accuracy=',scores[1])
# Out:
# 10000/10000 [==============================] - 1s 52us/step
#
# accuracy= 0.9802
